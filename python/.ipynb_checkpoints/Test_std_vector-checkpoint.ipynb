# %%
from standard_vector import DynamicArray

# %%
# Instantiate 
arr = DynamicArray() 
# Append new element 
arr.append(1) 
len(arr)
# Out:
# 1

# %%
arr = DynamicArray() 
for i in range(100):
    arr.append(i)
    print("num elements in array: ", len(arr))
    print("capacity array: ", arr.capacity)
for i in range(50):
    print i
# Out:
# ('num elements in array: ', 1)
# ('capacity array: ', 1)
# ('num elements in array: ', 2)
# ('capacity array: ', 2)
# ('num elements in array: ', 3)
# ('capacity array: ', 4)
# ('num elements in array: ', 4)
# ('capacity array: ', 4)
# ('num elements in array: ', 5)
# ('capacity array: ', 8)
# ('num elements in array: ', 6)
# ('capacity array: ', 8)
# ('num elements in array: ', 7)
# ('capacity array: ', 8)
# ('num elements in array: ', 8)
# ('capacity array: ', 8)
# ('num elements in array: ', 9)
# ('capacity array: ', 16)
# ('num elements in array: ', 10)
# ('capacity array: ', 16)
# ('num elements in array: ', 11)
# ('capacity array: ', 16)
# ('num elements in array: ', 12)
# ('capacity array: ', 16)
# ('num elements in array: ', 13)
# ('capacity array: ', 16)
# ('num elements in array: ', 14)
# ('capacity array: ', 16)
# ('num elements in array: ', 15)
# ('capacity array: ', 16)
# ('num elements in array: ', 16)
# ('capacity array: ', 16)
# ('num elements in array: ', 17)
# ...
